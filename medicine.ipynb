# %%
import pandas as pd
import numpy as np

df=pd.read_csv('Dataset/medicine_dataset.csv')
df.head()
# Out:
# /tmp/ipykernel_8688/4015164477.py:4: DtypeWarning: Columns (42,43,44,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Dataset/medicine_dataset.csv')
#    id                      name                     substitute0  \
# 0   1  augmentin 625 duo tablet  Penciclav 500 mg/125 mg Tablet
# 1   2       azithral 500 tablet         Zithrocare 500mg Tablet
# 2   3          ascoril ls syrup                 Solvin LS Syrup
# 3   4      allegra 120mg tablet                    Lcfex Tablet
# 4   5            avil 25 tablet              Eralet 25mg Tablet
#
#               substitute1              substitute2            substitute3  \
# 0  Moxikind-CV 625 Tablet  Moxiforce-CV 625 Tablet     Fightox 625 Tablet
# 1         Azax 500 Tablet          Zady 500 Tablet  Cazithro 500mg Tablet
# 2       Ambrodil-LX Syrup        Zerotuss XP Syrup         Capex LS Syrup
# 3     Etofex 120mg Tablet     Nexofex 120mg Tablet    Fexise 120mg Tablet
# ...

# %% [markdown]
# ### There are too much information that we currently do not wish to use
# Hence we go froward and remove the ones that we do not want to use and then carry forward with the processing

# %%
df.shape
# Out:
# (248218, 58)

# %%
print(df.columns.get_loc("use0"))
print(len(df.columns))
# Out:
# 49
# 58

# %%
df = df.iloc[:, [0, 1, 2, 3, 4, 7, 8, 9, 49]]
df.head()
# Out:
#    id                      name                     substitute0  \
# 0   1  augmentin 625 duo tablet  Penciclav 500 mg/125 mg Tablet
# 1   2       azithral 500 tablet         Zithrocare 500mg Tablet
# 2   3          ascoril ls syrup                 Solvin LS Syrup
# 3   4      allegra 120mg tablet                    Lcfex Tablet
# 4   5            avil 25 tablet              Eralet 25mg Tablet
#
#               substitute1              substitute2 sideEffect0  \
# 0  Moxikind-CV 625 Tablet  Moxiforce-CV 625 Tablet    Vomiting
# 1         Azax 500 Tablet          Zady 500 Tablet    Vomiting
# 2       Ambrodil-LX Syrup        Zerotuss XP Syrup      Nausea
# 3     Etofex 120mg Tablet     Nexofex 120mg Tablet    Headache
# 4                     NaN                      NaN  Sleepiness
#
#         sideEffect1     sideEffect2  \
# 0            Nausea        Diarrhea
# 1            Nausea  Abdominal pain
# 2          Vomiting        Diarrhea
# 3        Drowsiness       Dizziness
# ...

# %% [markdown]
# ### Now we have successfully cleaned the dataset to only include the data that will be of our use

# %%
# to find the data in the column name for 'paracetamol'
print(df[df['name']=='paracetamol'])
# Out:
# Empty DataFrame
# Columns: [id, name, substitute0, substitute1, substitute2, sideEffect0, sideEffect1, sideEffect2, use0]
# Index: []

# %%
print(df[df['name']=='jackson paracetamol 500 tablet'])
# Out:
#             id                            name          substitute0  \
# 121199  121200  jackson paracetamol 500 tablet  Calpol 500mg Tablet
#
#             substitute1  substitute2   sideEffect0 sideEffect1 sideEffect2  \
# 121199  Dolo 500 Tablet  T-98 Tablet  Stomach pain      Nausea    Vomiting
#
#                 use0
# 121199   Pain relief

# %%
def what_use(med_name):
    if med_name in df['name'].unique():
        return(df[df['name'] == med_name]['use0'].unique())
    else:
        return("Not found")
    
def side_effects(med_name):
    if med_name in df['name'].unique():
        return(df[df['name'] == med_name]['sideEffects0'].unique(), df[df['name'] == med_name]['sideEffects1'].unique(), 
                df[df['name'] == med_name]['sideEffects2'].unique())
    else:
        return("Not found")
    
def substitue_meds(med_name):
    if med_name in df['name'].unique():
        return(df[df['name'] == med_name]['substitute0'].unique(), df[df['name'] == med_name]['substitute1'].unique(), 
                df[df['name'] == med_name]['substitute2'].unique())
    else:
        return("Not found")
